# %% [markdown]
# <a href="https://colab.research.google.com/github/esesancr/devf_DS/blob/main/Challenge_Lenguaje_de_Programaci%C3%B3n_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CHALLENGE: LENGUAJE DE PROGRAMACIÓN PYTHON**

# %% [markdown]
# Una vez visto el ***Hands - On: Lenguaje de programación python***, se presentan la siguientes actividades para que el alumnado pueda repasar y reforzar lo aprendido dentro de la clase.

# %% [markdown]
# Dentro de la siguiente dinámica, **se creará una agenda de cinco contactos** haciendo uso de las **estructuras de datos** utilizando **Python**.
#
# Donde los datos que debe contener cada contacto de la angenda son:
#
# *   **Nombre**
# *   **Teléfono**
# *   **Correo**

# %%
agenda = [
    {"Nombre": "Chica", "telefono": "11-1111-1111", "correo": "chica@outlook.com"},
    {"Nombre": "Cometa", "telefono": "22-2222-2222", "correo": "cometa@outlook.com"},
    {"Nombre": "Margarito", "telefono": "33-3333-3333", "correo": "margarito@outlook.com"},
    {"Nombre": "Buchona", "telefono": "44-4444-4444", "correo": "buchona@outlook.com"},
    {"Nombre": "Nino", "telefono": "55-5555-5555", "correo": "nino@outlook.com"},
]

def listar_contactos(agenda):
    print("=== Agenda ===")
    for i, c in enumerate(agenda, start=1):
        print(f"{i}. {c['nombre']} | Tel: {c['telefono']} | Email: {c['correo']}")
